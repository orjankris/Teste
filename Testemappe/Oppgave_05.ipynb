# %% [markdown]
# # Oppgave 5
# Se oppbygging av studiet for BØA i Harstad. Lag en ordbok der BED-1301, BED-1304, FIL-0700 og BED-2303 er nøkler, og verdier er navn på emnet, antall studiepoeng og vurderingsform.

# %%
# Legger de fire emnene inn som en nøstet ordbok
emner = {'BED-1301': {'Navn': 'Matematikk for økonomer', 'Stp': 7.5, 'Vurdering': 'Skriftlig'},
         'BED-1304': {'Navn': 'Python-Lab', 'Stp': 7.5, 'Vurdering': 'Skriftlig'},
         'FIL-0700': {'Navn': 'Examen philosophicum', 'Stp': 10, 'Vurdering': 'Muntlig'},
         'BED-2303': {'Navn': 'Investering og finansiering', 'Stp': 7.5, 'Vurdering': 'Muntlig'}
         }

# %%
# Eksempel: Henter ut vurderingsform for BED-1304
emner['BED-1304']['Vurdering']
# Out:
# 'Skriftlig'

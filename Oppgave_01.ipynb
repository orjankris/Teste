# %% [markdown]
# # Oppgave 1
# Regn ut følgende:
#
# $\Large \frac{5^{4/3}-2}{5-(4/3)^2} \quad $ og $ \quad \Large \sqrt[5]{\frac{4/3}{\sqrt{2}}}$

# %%
# Første regneoppgave
(5**(4/3) - 2) / (5 - (4/3)**2)
# Out:
# 2.032721296567288

# %%
# Andre regneoppgave
((4/3) / 2**(1/2)) ** (1/5)
# Out:
# 0.9882907891208811
